# %% [markdown]
# # Чем мы будем заниматься на курсе по введению в DS и ML?

# %% [markdown]
# Использовать модели машинного обучения для решения задач классификации и регрессии

# %%
#Pandas, Dataframes
import pandas as pd
import numpy as np

# %%
students_performance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
students_performance.head(20)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
students_performance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
students_performance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
students_performance.shape
# Out:
# (1000, 8)

# %%
students_performance.groupby('gender').aggregate({'writing score' : 'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
students_performance.size
# Out:
# 8000

# %%
students_performance.iloc[0:5, 0:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
students_performance.iloc[[1,3,4],[1,2,3]]
# Out:
#   race/ethnicity parental level of education         lunch
# 1        group C                some college      standard
# 3        group A          associate's degree  free/reduced
# 4        group C                some college      standard

# %%
students_performance_with_names = students_performance.iloc[[0,3,4,7,8]]

# %%
students_performance_with_names.index = ['Ann', 'Olyan', 'Mike', 'Nik', 'Son']

# %%
students_performance_with_names
# Out:
#        gender race/ethnicity parental level of education         lunch  \
# Ann    female        group B           bachelor's degree      standard
# Olyan    male        group A          associate's degree  free/reduced
# Mike     male        group C                some college      standard
# Nik      male        group B                some college  free/reduced
# Son      male        group D                 high school  free/reduced
#
#       test preparation course  math score  reading score  writing score
# Ann                      none          72             72             74
# Olyan                    none          47             57             44
# Mike                     none          76             78             75
# Nik                      none          40             43             39
# Son                 completed          64             64             67

# %%
students_performance_with_names.loc[['Olyan', 'Nik'], ['gender', 'lunch']]
# Out:
#       gender         lunch
# Olyan   male  free/reduced
# Nik     male  free/reduced

# %%
students_performance_with_names.iloc[0,:]
# Out:
# gender                                    female
# race/ethnicity                           group B
# parental level of education    bachelor's degree
# lunch                                   standard
# test preparation course                     none
# math score                                    72
# reading score                                 72
# writing score                                 74
# Name: Ann, dtype: object

# %%
type(students_performance_with_names.iloc[0,:])
# Out:
# pandas.core.series.Series

# %%
my_series_1 = pd.Series([1,2,3], index = ['putin', 'is', 'bad'])
my_series_2 = pd.Series([1,2,3], index = ['somebody', 'is', 'better'])

# %%
students_performance_with_names['gender'].shape
# Out:
# (5,)

# %%
students_performance.loc[:5]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# 5                    none          71             83             78

# %% [markdown]
# Титаник

# %%
Titanic = pd.read_csv('https://stepik.org/media/attachments/course/4852/titanic.csv')
Titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Titanic.shape
# Out:
# (891, 12)

# %%
Titanic.dtypes.value_counts()
# Out:
# int64      5
# object     5
# float64    2
# dtype: int64

# %% [markdown]
# Я освоила основы библиотеки Pandas,урааааа.Спасибо преподавателю! Ты умница, ложись спать)

# %% [markdown]
# # Фильтрация данных

# %%
 students_performance.loc[students_performance.gender == 'female', ['gender', 'writing score']]
# Out:
#      gender  writing score
# 0    female             74
# 1    female             88
# 2    female             93
# 5    female             78
# 6    female             92
# ..      ...            ...
# 993  female             74
# 995  female             95
# 997  female             65
# 998  female             77
# 999  female             86
#
# [518 rows x 2 columns]

# %%
mean_writing_score = students_performance['writing score'].mean()

# %%
students_performance.loc[students_performance['writing score'] > mean_writing_score]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
True or False
# Out:
# True

# %%
mean_writing_score = students_performance['writing score'].mean()

# %%
students_performance.loc[students_performance.gender == 'female'].head()

# %%
query = (students_performance['writing score'] > mean_writing_score) & ( students_performance.gender =='female')

# %%
students_performance.loc[query].head()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 5                    none          71             83             78
# 6               completed          88             95             92

# %%
students_performance.loc[students_performance['lunch'] == 'free/reduced']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
(students_performance['lunch'] == 'free/reduced').mean()
# Out:
# 0.355

# %%
students_performance.loc[students_performance['lunch'] == 'free/reduced'].var()
# дисперсия оценок студентов с урезанным ланчем
# Out:
# math score       229.824270
# reading score    221.871139
# writing score    238.202881
# dtype: float64

# %%
students_performance.loc[students_performance['lunch'] == 'standard'].var()
# дисперсия оценок студентов со стандартным ланчем
# Out:
# math score       186.418089
# reading score    191.285560
# writing score    205.620887
# dtype: float64

# %%
students_performance.loc[students_performance['lunch'] == 'standard'].mean()
# средние значения оценок студентов со стандартным ланчем
# Out:
# math score       70.034109
# reading score    71.654264
# writing score    70.823256
# dtype: float64

# %%
students_performance.loc[students_performance['lunch'] == 'free/reduced'].mean()
#  средние значения оценок студентов с урезанным ланчем
# Out:
# math score       58.921127
# reading score    64.653521
# writing score    63.022535
# dtype: float64

# %%
students_performance = students_performance \
    .rename(columns =
            {'parental level of education' : 'parental_level_of_education',
             'test preparation course' : 'test_preparation_course',
             'math score' : 'math_score',
             'reading score' : 'reading_score' ,
             'writing score' : 'writing_score'})

# %%
students_performance
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
writing_score_query = 90

# %%
students_performance.query("writing_score > @writing_score_query")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 94   female        group B                some college      standard
# 106  female        group D             master's degree      standard
# 110  female        group D          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 962  female        group E          associate's degree      standard
# 970  female        group D           bachelor's degree      standard
# 979  female        group C          associate's degree      standard
# 983  female        group A                some college      standard
# 995  female        group E             master's degree      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
# отбираем отдельные колонки
students_performance[['math_score', 'reading_score']].head()
# Out:
#    math_score  reading_score
# 0          72             72
# 1          69             90
# 2          90             95
# 3          47             57
# 4          76             78

# %%
score_columns = [i for i in list(students_performance) if 'score' in i]

# %%
score_columns
# Out:
# ['math score', 'reading score', 'writing score']

# %%
students_performance.filter(like = 'score')
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
students_performance.filter(like = '1', axis = 0)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# 13     male        group A                some college      standard
# ..      ...            ...                         ...           ...
# 951  female        group D                some college      standard
# 961  female        group D            some high school  free/reduced
# 971    male        group C            some high school      standard
# 981    male        group D            some high school      standard
# 991  female        group B            some high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
selected_columns = pd.read_csv('https://stepik.org/media/attachments/course/4852/column_hell.csv')

# %%
selected_columns.filter(like = '-')
# Out:
#      umeca-4  kudbpyw-3       g-3       v-9     fla-6  hwtbyrkp-5
# 0   0.016124   0.430787  0.202407  0.725508  0.305076    0.979296
# 1   0.507115   0.671662  0.864249  0.867818  0.358859    0.160520
# 2   0.003274   0.286411  0.928865  0.719159  0.340235    0.734612
# 3   0.784139   0.863717  0.175446  0.554744  0.049325    0.621132
# 4   0.011265   0.206172  0.044151  0.163643  0.048806    0.437836
# ..       ...        ...       ...       ...       ...         ...
# 95  0.220817   0.434444  0.601738  0.146333  0.918888    0.216499
# 96  0.474131   0.176011  0.359793  0.104707  0.257690    0.066934
# 97  0.091637   0.871606  0.121075  0.907699  0.313184    0.788592
# 98  0.360106   0.172385  0.015285  0.019571  0.060751    0.403166
# 99  0.669284   0.701505  0.481430  0.024944  0.644989    0.702003
#
# [100 rows x 6 columns]
