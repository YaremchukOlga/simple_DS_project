# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students_performance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
students_performance = students_performance.rename(columns = {'math score':'math_score', \
    'reading score':'reading_score','writing score':'writing_score',\
    'parental level of education':'parental_level_of_education', \
    'test preparation course':'test_preparation_course'})

# %%
students_performance
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
students_performance.math_score.hist()
# Out:
# <AxesSubplot:>

# %%
students_performance.plot.scatter(x = 'math_score', y = 'reading_score')
# Out:
# <AxesSubplot:xlabel='math_score', ylabel='reading_score'>

# %%
ax = sns.lmplot(x = 'math_score', y = 'reading_score', hue = 'gender', data = students_performance, fit_reg=False)
ax.set_xlabels('Math score')
ax.set_ylabels('Reading score')

# %%
new_frame = pd.DataFrame(data = [35000,25000,37000,40000,51000], index = [1,2,3,4,5])

# %%
new_frame.plot()
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x=df.index, y=df.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
data = pd.read_clipboard()

# %%
data.plot.scatter(x='x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv', index_col = False)
df
# Out:
#   Unnamed: 0  species0  species1  species2  species3  species4
# 0   species0  0.536029  0.920292  0.679708  0.840606  0.430842
# 1   species1  0.920292  0.862417  0.887593  0.769754  0.203214
# 2   species2  0.679708  0.887593  0.595156  0.003435  0.096052
# 3   species3  0.840606  0.769754  0.003435  0.458870  0.029251
# 4   species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(df.iloc[:,1:], cmap = "viridis")
# ваш код для создания теплокарты, укажите параметр cmap="viridis" для той же цветовой схемы
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
dota_data = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv', sep = ',')
dota_data
# read the file from link and visualize it
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
[(str_roles.count(',') + 1) for str_roles in dota_data.roles]
# Out:
# [3,
#  4,
#  4,
#  5,
#  4,
#  3,
#  4,
#  3,
#  5,
#  5,
#  2,
#  4,
#  4,
#  4,
#  4,
#  6,
#  5,
#  5,
#  6,
#  5,
#  5,
#  1,
#  6,
#  4,
#  4,
#  5,
#  5,
#  4,
#  3,
#  2,
#  3,
#  4,
#  3,
#  2,
#  4,
#  3,
#  4,
#  3,
#  5,
#  5,
#  5,
#  4,
#  2,
#  2,
#  2,
#  4,
#  3,
#  6,
#  3,
#  4,
#  5,
#  5,
#  5,
#  4,
#  3,
#  3,
#  5,
#  3,
#  5,
#  4,
#  2,
#  2,
#  4,
#  4,
#  3,
#  3,
#  3,
#  5,
#  4,
#  5,
#  3,
#  6,
#  5,
#  5,
#  3,
#  5,
#  5,
#  4,
#  4,
#  5,
#  6,
#  5,
#  5,
#  4,
#  3,
#  4,
#  4,
#  6,
#  4,
#  3,
#  5,
#  4,
#  3,
#  4,
#  5,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  4,
#  5,
#  2,
#  5,
#  5,
#  5,
#  3,
#  5,
#  4,
#  3,
#  3,
#  4,
#  4,
#  6,
#  4,
#  4]

# %%
dota_data['roles_number'] = [(str_roles.count(',') + 1) for str_roles in dota_data.roles]
dota_data
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
dota_data.roles_number.mode()
dota_data.hist(column = 'roles_number', xlabelsize = 10)
# Out:
# array([[<AxesSubplot:title={'center':'roles_number'}>]], dtype=object)

# %%
#flowers for Adel
iris = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', index_col = 0)
iris
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
for column in iris:
    sns.kdeplot(data = iris)

# %%
sns.violinplot(y = iris['petal length'], orient = 'v')
# Out:
# <AxesSubplot:ylabel='petal length'>

# %%
#зависимость пар переменных
sns.pairplot(iris, hue = 'species')

# %%
iris.corr()
# Out:
#               sepal length  sepal width  petal length  petal width   species
# sepal length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal width       0.817954    -0.356544      0.962757     1.000000  0.956464
# species           0.782561    -0.419446      0.949043     0.956464  1.000000

# %%
my_data = pd.DataFrame(data = {'type':['A','A', 'B','B'],'value':[10,14,12,23]})

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')
my_stat
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 4     0  10.0  B -1.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [500 rows x 4 columns]

# %%
subset_1 = my_stat.iloc[:10,[0,2]]

# %%
subset_11
# Out:
#    V1 V3
# 0   2  B
# 1  -1  B
# 2   0  A
# 3   2  A
# 4   0  B
# 5   2  A
# 6   0  A
# 7   1  A
# 8   0  B
# 9  -1  A

# %%
subset_22 = my_stat.iloc[:,[1,3]].drop(my_stat.index[[0,4]])

# %%
subset_1 = my_stat.loc[(my_stat.V1 > 0) & (my_stat.V3 =='A')]
subset_1
# Out:
#      V1    V2 V3   V4
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# 7     1   9.0  A  1.0
# 10    1  10.0  A  1.0
# 13    1  12.0  A  3.0
# ..   ..   ... ..  ...
# 491   4   7.0  A  2.0
# 494   1  11.0  A  1.0
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 498   1  11.0  A  2.0
#
# [88 rows x 4 columns]

# %%
subset_2 = my_stat.loc[(my_stat.V2 != 10) | (my_stat.V4 >= 10)]

# %%
my_stat['V5'] = my_stat.V1 + my_stat.V4
my_stat
# Out:
#      V1    V2 V3   V4   V5
# 0     2  13.0  B  1.0  3.0
# 1    -1   7.0  B  1.0  0.0
# 2     0  11.0  A  0.0  0.0
# 3     2  11.0  A  2.0  4.0
# 4     0  10.0  B -1.0 -1.0
# ..   ..   ... ..  ...  ...
# 495   1   8.0  A -1.0  0.0
# 496   3   8.0  A  1.0  4.0
# 497  -1  11.0  B  2.0  1.0
# 498   1  11.0  A  2.0  3.0
# 499   0   8.0  B  1.0  1.0
#
# [500 rows x 5 columns]

# %%
my_stat['V6'] = my_stat.agg({'V2':np.log})
my_stat
# Out:
#      V1    V2 V3   V4   V5        V6
# 0     2  13.0  B  1.0  3.0  2.564949
# 1    -1   7.0  B  1.0  0.0  1.945910
# 2     0  11.0  A  0.0  0.0  2.397895
# 3     2  11.0  A  2.0  4.0  2.397895
# 4     0  10.0  B -1.0 -1.0  2.302585
# ..   ..   ... ..  ...  ...       ...
# 495   1   8.0  A -1.0  0.0  2.079442
# 496   3   8.0  A  1.0  4.0  2.079442
# 497  -1  11.0  B  2.0  1.0  2.397895
# 498   1  11.0  A  2.0  3.0  2.397895
# 499   0   8.0  B  1.0  1.0  2.079442
#
# [500 rows x 6 columns]

# %%
my_stat = my_stat.rename(columns = {'V1' : 'session_value','V2': 'group','V3':'time','V4':'n_users'})

# %%
my_stat
# Out:
#      session_value  group time  n_users   V5        V6
# 0                2   13.0    B      1.0  3.0  2.564949
# 1               -1    7.0    B      1.0  0.0  1.945910
# 2                0   11.0    A      0.0  0.0  2.397895
# 3                2   11.0    A      2.0  4.0  2.397895
# 4                0   10.0    B     -1.0 -1.0  2.302585
# ..             ...    ...  ...      ...  ...       ...
# 495              1    8.0    A     -1.0  0.0  2.079442
# 496              3    8.0    A      1.0  4.0  2.079442
# 497             -1   11.0    B      2.0  1.0  2.397895
# 498              1   11.0    A      2.0  3.0  2.397895
# 499              0    8.0    B      1.0  1.0  2.079442
#
# [500 rows x 6 columns]

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat_1.csv')
my_stat
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            NaN    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            NaN    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B      -11
# 9            0.0     9     A      -20

# %%
my_stat.fillna(value = {'session_value':0},inplace=True)

# %%
my_stat
